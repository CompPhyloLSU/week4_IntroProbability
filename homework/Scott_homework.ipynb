# %% [markdown]
# # Week 4 Homework - P-values

# %% [markdown]
# You flip a coin 20 times and observe 5 heads. This seems low if the coin is fair, but just how improbable is it? One way to address this is to simulate a large number of 20 coin flips and see how many of these simulations result in 5 or fewer heads.

# %%
# In this cell, run your binomial simulations. There are at least two different ways to do this. 
# One involves a for loop. Be sure to store the results (# heads) in a vector. To find the function for binomial
# draws, remember the name of the function we've drawn from before - runifInt. To see all possible functions in
# RevBayes, you can use ls(all=TRUE).
clear()
numflips = 10000
for(k in 1:numflips){
    count[k] = 0
}
for(i in 1:numflips){
    count[i] = rbinomial(1, .5, 20)
}
print(count)
# Out:
# 13,9,10,9,11,10,7,8,10,13,8,7,13,9,11,8,7,7,8,11,8,9,14,11,7,9,12,10,9,12,8,11,10,12,10,7,13,11,11,7,9,9,8,12,9,10,9,12,8,13,9,10,12,8,8,10,6,9,11,12,10,9,12,11,12,13,7,8,10,10,13,9,8,13,7,12,8,10,9,9,8,10,12,11,14,9,13,11,9,6,10,8,10,12,11,6,13,15,8,11,11,9,10,6,9,10,9,8,5,12,9,15,8,13,8,13,9,8,12,11,8,12,10,11,8,11,9,8,7,15,9,11,12,12,10,12,10,7,14,9,13,9,10,11,9,9,9,11,11,10,8,16,12,8,14,9,10,10,9,13,8,11,7,10,14,10,12,11,6,8,12,10,9,10,9,13,10,9,9,11,13,12,8,9,6,15,9,13,8,10,8,10,10,10,10,8,10,6,13,8,12,11,12,12,13,12,10,12,9,12,14,11,10,8,7,8,12,10,8,11,14,13,12,9,10,8,11,13,12,10,12,9,11,7,11,14,11,11,10,12,12,10,9,7,10,11,8,9,12,7,10,8,11,11,10,10,12,15,8,8,13,15,14,10,9,8,10,6,10,9,10,11,10,9,12,6,12,7,8,12,9,10,12,14,6,9,12,13,12,9,11,10,5,11,12,14,11,12,12,11,5,11,8,10,7,10,10,14,10,12,10,10,10,12,10,13,7,11,6,11,8,12,11,10,10,11,13,9,11,12,12,9,13,10,10,10,8,11,8,8,11,7,13,8,8,9,7,10,10,12,10,10,7,15,8,11,11,11,13,8,6,13,5,8,10,10,7,8,11,14,7,15,10,10,10,14,8,10,11,7,11,9,13,11,13,11,12,7,9,10,7,10,12,12,9,9,10,10,9,12,9,7,6,13,9,6,5,12,10,9,11,8,10,12,8,11,8,15,9,11,8,12,9,11,10,11,11,5,8,9,11,11,11,7,8,15,9,7,10,5,14,6,16,9,10,12,7,12,6,10,10,11,8,12,11,11,10,10,8,12,7,11,10,13,9,8,13,13,4,9,9,11,8,12,13,7,7,9,12,12,11,13,14,13,11,8,12,8,11,13,10,14,14,8,9,7,10,10,6,6,11,14,12,6,6,11,11,9,9,9,8,7,6,14,8,12,11,13,13,9,12,9,11,11,10,10,10,6,11,12,9,6,9,11,8,13,10,12,12,13,10,12,10,9,12,10,9,9,11,9,7,12,12,12,11,9,11,11,10,11,10,12,15,12,15,8,12,11,6,12,9,6,12,12,13,9,14,11,9,7,9,7,11,8,12,12,7,11,11,11,9,14,10,9,7,10,11,5,13,8,15,10,6,9,11,10,9,10,9,13,9,11,9,6,12,9,6,12,11,8,12,13,6,17,9,10,12,13,11,11,8,13,10,10,9,12,10,12,9,10,10,13,11,8,8,12,13,9,12,11,9,7,12,8,5,10,10,10,9,12,8,13,12,10,13,10,12,7,14,8,7,9,9,8,11,10,8,14,11,9,14,8,12,12,12,9,6,10,14,12,8,11,10,10,7,11,10,10,13,17,12,13,
# Now you'll need to compare your observation (5 heads) to your simulations. Using a `for` loop, go through your results and count the number of simulated values that are less than or equal to your observed value. Convert your count into a frequency by dividing by the total number of simulations you ran.

# %%
# In this cell, compare your simulated and observed values.

# First, initialize a variable to hold your count of simulated values less than the observed

# Set up a for loop and tally the number of sims with <= 5 heads.
heads[1] = 0
heads[2] = 0
for (j in 1:numflips) {
    if (count[j][1] <= 5){
        heads[1] += 1
    } else {
        heads[2] += 1
    }
}
print(heads)

# Display the frequency of sims with <= 5 heads here
print(heads[1]/numflips)
# Out:
# 190,9810
# 0.019

# %%
Using 10,000 simulations the odds of getting 5 heads for 20 flips was around 0.019. I would not believe that the coin is most likely fair.

# %% [markdown]
# How probable was the observed number of heads? Do you believe your coin to be fair?
#
# Another way to get this probability is not using simulations. For standard distributions like the binomial, there are built-in probability mass functions with known probabilities for different outcomes. These are similar to the functions used to draw values from a distribution, but in this case they start with a `d`. For the binomial, this function takes 4 arguments:
#
# 1. number of successes (heads)
# 2. probability of success (0.5 for a fair coin)
# 3. number of trials (coin flips)
# 4. a boolean to see if you want the log of the probability (use FALSE here)
#
# To get the total probability of 0, 1, 2, 3, 4, and 5, you'll need to call this function once for each number of successes and add the probabilities together. How does this compare to the value you estimated above using simulations?

# %%
# In this cell, use RevBayes built-in PMF for the binomial to calculate the tail-area probability of <= 5 heads.
prob0 = dbinomial(0, 0.5, 20, FALSE)
prob1 = dbinomial(1, 0.5, 20, FALSE)
prob2 = dbinomial(2, 0.5, 20, FALSE)
prob3 = dbinomial(3, 0.5, 20, FALSE)
prob4 = dbinomial(4, 0.5, 20, FALSE)
prob5 = dbinomial(5, 0.5, 20, FALSE)
prob_total = (prob0 + prob1 +prob2 + prob3 + prob4 +  prob5)
print(prob_total)
# Out:
# 0.02069473

# %%
My simulations found 0.019 and this method found 0.02. They are very close and both lead me to believe that the coin is not fair.

# %% [markdown]
# The probabilities you've just calculated or estimated above are the lower one-tailed p-values associated with observing 5 heads if your null hypothesis is a fair coin. What is the standard threshold for p-values in order to reject the null hypothesis (often called alpha)? Using this value, would you reject the hypothesis of a fair coin?
#
# What's a two-tailed p-value? How would you calculate that in this case? Using a two-tailed value, would you still reject the fair coin model?

# %%
The standard threshold for a p-value is 0.05. Here I would reject the null hypothesis.
The one tailed test looks at one end of the distribution, here the lower, and looks at the 5%. The two tailed test 
would look at both extremes so each tail cutoff would be .025. You would have to test both the bottom and top of the distribution.

# %%
prob0 = dbinomial(0, 0.5, 20, FALSE)
prob1 = dbinomial(1, 0.5, 20, FALSE)
prob2 = dbinomial(2, 0.5, 20, FALSE)
prob3 = dbinomial(3, 0.5, 20, FALSE)
prob4 = dbinomial(4, 0.5, 20, FALSE)
prob5 = dbinomial(5, 0.5, 20, FALSE)
prob20 = dbinomial(20, 0.5, 20, FALSE)
prob19 = dbinomial(19, 0.5, 20, FALSE)
prob18 = dbinomial(18, 0.5, 20, FALSE)
prob17 = dbinomial(17, 0.5, 20, FALSE)
prob16 = dbinomial(16, 0.5, 20, FALSE)
prob15 = dbinomial(15, 0.5, 20, FALSE)
prob_total = (prob0 + prob1 + prob2 + prob3 + prob4 + prob5 + prob20 + prob19 +  prob18 + prob17 + prob16 + prob15)
prob_lower = (prob0 + prob1 + prob2 + prob3 + prob4 + prob5)
prob_higher = (prob20 + prob19 +  prob18 + prob17 + prob16 + prob15)
print(prob_total, prob_lower, prob_higher)
# Out:
# 0.04138947	0.02069473	0.02069473

# %%
You would still reject the null with a two tailed test.
